# %%
import ccxt
import pandas as pd

# %%
exchange = ccxt.ftx({
    'enableRateLimit': True,
})

# %%
ftx_df = exchange.public_get_funding_rates()['result']

# %%
for i in ftx_df:
    print(i)
# Out:
# {'future': 'YFI-PERP', 'rate': '0.000021', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'XAUT-PERP', 'rate': '0.000028', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'HBAR-PERP', 'rate': '-1e-6', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'UNI-PERP', 'rate': '0.00001', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'UNISWAP-PERP', 'rate': '0.000089', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'BNB-PERP', 'rate': '-0.00006', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'HNT-PERP', 'rate': '0.000014', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'YFII-PERP', 'rate': '6e-6', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'LINA-PERP', 'rate': '0.000024', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'VET-PERP', 'rate': '5e-6', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'GRT-PERP', 'rate': '0.000017', 'time': '2022-01-15T07:00:00+00:00'}
# {'future': 'POLIS-PERP', 'rate': '0.000016', 'time': '2022-01-15T07:00:00+00:00'}
# ...

# %%
for i in ftx_df:
    print(i['future'])
    print(float(i['rate'])*100)
    print("")
# Out:
# YFI-PERP
# 0.0021
#
# XAUT-PERP
# 0.0028
#
# HBAR-PERP
# -9.999999999999999e-05
#
# UNI-PERP
# 0.001
#
# UNISWAP-PERP
# 0.0089
#
# BNB-PERP
# -0.006
#
# HNT-PERP
# 0.0014
#
# YFII-PERP
# 0.0006000000000000001
#
# LINA-PERP
# 0.0024000000000000002
#
# VET-PERP
# 0.0005
#
# GRT-PERP
# 0.0017
#
# POLIS-PERP
# 0.0015999999999999999
#
# BIT-PERP
# -0.0095
#
# CUSDT-PERP
# 0.0011
#
# NEAR-PERP
# -0.0014
#
# STEP-PERP
# 0.0007999999999999999
#
# CHZ-PERP
# -0.001
#
# DASH-PERP
# 9.999999999999999e-05
#
# LEO-PERP
# -0.0033000000000000004
#
# SRM-PERP
# -0.0005
#
# KIN-PERP
# 0.0026999999999999997
#
# SPELL-PERP
# 0.0022
#
# 1INCH-PERP
# -0.0033000000000000004
#
# KSHIB-PERP
# -0.0063
#
# SLP-PERP
# -0.029500000000000002
#
# REN-PERP
# 0.0018
#
# FTM-PERP
# -0.0015
#
# AXS-PERP
# -0.0059
#
# FLOW-PERP
# 0.00039999999999999996
#
# ONT-PERP
# 0.0018
#
# DAWN-PERP
# -0.0246
#
# GALA-PERP
# 0.0007999999999999999
#
# DEFI-PERP
# 0.0026
#
# BCH-PERP
# 0.0005
#
# TRYB-PERP
# -0.0083
#
# KSOS-PERP
# ...
