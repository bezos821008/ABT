# %%
import ccxt

# %%
exchange = ccxt.bitfinex()

# %%
cy_list = exchange.load_markets()

# %%
markets = ccxt.bitfinex().load_markets()

# %%
for i in markets:
    str1 = i.split('/')
    
    if str1[1]=='USDT' or str1[1]=='USD':
        print(str1)
        #print(str2)
        #markets.append(str2)
# Out:
# ['BTC', 'USD']
# ['LTC', 'USD']
# ['ETH', 'USD']
# ['ETC', 'USD']
# ['RRT', 'USD']
# ['ZEC', 'USD']
# ['XMR', 'USD']
# ['DASH', 'USD']
# ['XRP', 'USD']
# ['IOTA', 'USD']
# ['EOS', 'USD']
# ['SAN', 'USD']
# ['OMG', 'USD']
# ['NEO', 'USD']
# ['ETP', 'USD']
# ['QTUM', 'USD']
# ['PNT', 'USD']
# ['BTG', 'USD']
# ['DATA', 'USD']
# ['QASH', 'USD']
# ['GNT', 'USD']
# ['SNT', 'USD']
# ['BAT', 'USD']
# ['MANA', 'USD']
# ['FUN', 'USD']
# ['ZRX', 'USD']
# ['TRX', 'USD']
# ['REP', 'USD']
# ['REQ', 'USD']
# ['LRC', 'USD']
# ['WAXP', 'USD']
# ['DAI', 'USD']
# ['BFT', 'USD']
# ['ODE', 'USD']
# ['ANT', 'USD']
# ['STORJ', 'USD']
# ['XLM', 'USD']
# ['XVG', 'USD']
# ['MKR', 'USD']
# ['KNC', 'USD']
# ['LYM', 'USD']
# ['UTK', 'USD']
# ['VEE', 'USD']
# ['ORS Group', 'USD']
# ['ZCN', 'USD']
# ['ESS', 'USD']
# ['IQ', 'USD']
# ['ZIL', 'USD']
# ['BNT', 'USD']
# ['XRA', 'USD']
# ['VET', 'USD']
# ['GOT', 'USD']
# ['XTZ', 'USD']
# ['YEED', 'USD']
# ['MLN', 'USD']
# ['OMN', 'USD']
# ['PNK', 'USD']
# ...
