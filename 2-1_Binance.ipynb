# %%
import ccxt
import pandas as pd

# %%
exchange = ccxt.binance({
    'enableRateLimit': True,
})
ba_response = exchange.fapiPublicGetPremiumIndex()
# df = pd.DataFrame(ba_response)
# df['nextFundingTime'] = pd.to_datetime(df['nextFundingTime'],unit='ms')
# df['time'] = pd.to_datetime(df['time'],unit='ms')
# df_1 = df[['symbol','time','nextFundingTime']]
# df_2 = df[['lastFundingRate']]

# %%
# for i in range(df_2.shape[0]):
#     df_2.iloc[i][0] = round(float(df_2.iloc[i][0])*100,3)

# %%
# df3 = df_1.merge(df_2, how='left', left_index=True, right_index=True)

# %%
cot = 0
for i in ba_response:
    print(i)
    print(i['symbol'])
    print(float(i['lastFundingRate'])*100)
    print("")
# Out:
# {'symbol': 'RAYUSDT', 'markPrice': '5.35745000', 'indexPrice': '5.36273726', 'estimatedSettlePrice': '5.36352026', 'lastFundingRate': '-0.00063718', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RAYUSDT
# -0.063718
#
# {'symbol': 'SUSHIUSDT', 'markPrice': '7.08500000', 'indexPrice': '7.08646848', 'estimatedSettlePrice': '7.10042937', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SUSHIUSDT
# 0.01
#
# {'symbol': 'CVCUSDT', 'markPrice': '0.33298000', 'indexPrice': '0.33303993', 'estimatedSettlePrice': '0.33331186', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CVCUSDT
# 0.01
#
# {'symbol': 'BTSUSDT', 'markPrice': '0.03180291', 'indexPrice': '0.03180259', 'estimatedSettlePrice': '0.03178084', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BTSUSDT
# 0.01
#
# {'symbol': 'HOTUSDT', 'markPrice': '0.00621000', 'indexPrice': '0.00621438', 'estimatedSettlePrice': '0.00621901', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# HOTUSDT
# 0.01
#
# {'symbol': 'ZRXUSDT', 'markPrice': '0.74290000', 'indexPrice': '0.74343061', 'estimatedSettlePrice': '0.74098451', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ZRXUSDT
# 0.01
#
# {'symbol': 'QTUMUSDT', 'markPrice': '8.90700000', 'indexPrice': '8.96669859', 'estimatedSettlePrice': '8.56310869', 'lastFundingRate': '-0.00007405', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# QTUMUSDT
# -0.007405
#
# {'symbol': 'IOTAUSDT', 'markPrice': '1.14856257', 'indexPrice': '1.14945089', 'estimatedSettlePrice': '1.14836339', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# IOTAUSDT
# 0.01
#
# {'symbol': 'BTCBUSD', 'markPrice': '43020.70000000', 'indexPrice': '43042.67145840', 'estimatedSettlePrice': '43058.61107568', 'lastFundingRate': '0.00009099', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BTCBUSD
# 0.009099
#
# {'symbol': 'WAVESUSDT', 'markPrice': '14.16700000', 'indexPrice': '14.17991189', 'estimatedSettlePrice': '14.17363136', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# WAVESUSDT
# 0.01
#
# {'symbol': 'ADAUSDT', 'markPrice': '1.26438193', 'indexPrice': '1.26436932', 'estimatedSettlePrice': '1.26745671', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ADAUSDT
# 0.01
#
# {'symbol': 'LITUSDT', 'markPrice': '2.56414502', 'indexPrice': '2.56418694', 'estimatedSettlePrice': '2.55981491', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LITUSDT
# 0.01
#
# {'symbol': 'NUUSDT', 'markPrice': '0.63920375', 'indexPrice': '0.64028680', 'estimatedSettlePrice': '0.64050211', 'lastFundingRate': '-0.00042008', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# NUUSDT
# -0.042008
#
# {'symbol': 'XTZUSDT', 'markPrice': '4.31360334', 'indexPrice': '4.31499927', 'estimatedSettlePrice': '4.31520424', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XTZUSDT
# 0.01
#
# {'symbol': 'BNBUSDT', 'markPrice': '493.86137400', 'indexPrice': '494.41326515', 'estimatedSettlePrice': '494.16384313', 'lastFundingRate': '-0.00076984', 'interestRate': '0', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BNBUSDT
# -0.07698400000000001
#
# {'symbol': 'AKROUSDT', 'markPrice': '0.01901189', 'indexPrice': '0.01903039', 'estimatedSettlePrice': '0.01902394', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# AKROUSDT
# 0.01
#
# {'symbol': 'HNTUSDT', 'markPrice': '33.47240097', 'indexPrice': '33.48986900', 'estimatedSettlePrice': '33.55452780', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# HNTUSDT
# 0.01
#
# {'symbol': 'ETCUSDT', 'markPrice': '32.89700000', 'indexPrice': '32.89766341', 'estimatedSettlePrice': '32.69390165', 'lastFundingRate': '-0.00004124', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ETCUSDT
# -0.004124
#
# {'symbol': 'XMRUSDT', 'markPrice': '224.70000000', 'indexPrice': '224.87018760', 'estimatedSettlePrice': '224.89862709', 'lastFundingRate': '-0.00005526', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XMRUSDT
# -0.0055260000000000005
#
# {'symbol': 'YFIUSDT', 'markPrice': '31980', 'indexPrice': '32010.87678170', 'estimatedSettlePrice': '32037.67934662', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# YFIUSDT
# 0.01
#
# {'symbol': 'FTTBUSD', 'markPrice': '45.18500000', 'indexPrice': '45.18661025', 'estimatedSettlePrice': '45.22058533', 'lastFundingRate': '0.00002243', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# FTTBUSD
# 0.002243
#
# {'symbol': 'ETHUSDT', 'markPrice': '3314.05757326', 'indexPrice': '3314.76546738', 'estimatedSettlePrice': '3316.02289147', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ETHUSDT
# 0.01
#
# {'symbol': 'ALICEUSDT', 'markPrice': '10.82851198', 'indexPrice': '10.83623257', 'estimatedSettlePrice': '10.83063973', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ALICEUSDT
# 0.01
#
# {'symbol': 'ALPHAUSDT', 'markPrice': '0.56644931', 'indexPrice': '0.56644366', 'estimatedSettlePrice': '0.56693602', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ALPHAUSDT
# 0.01
#
# {'symbol': 'SFPUSDT', 'markPrice': '1.10970000', 'indexPrice': '1.10976510', 'estimatedSettlePrice': '1.11236842', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SFPUSDT
# 0.01
#
# {'symbol': 'REEFUSDT', 'markPrice': '0.01409700', 'indexPrice': '0.01410665', 'estimatedSettlePrice': '0.01412093', 'lastFundingRate': '-0.00003879', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# REEFUSDT
# -0.003879
#
# {'symbol': 'BATUSDT', 'markPrice': '1.05610000', 'indexPrice': '1.05702241', 'estimatedSettlePrice': '1.05671482', 'lastFundingRate': '0.00004790', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BATUSDT
# 0.00479
#
# {'symbol': 'DOGEUSDT', 'markPrice': '0.19213000', 'indexPrice': '0.19215466', 'estimatedSettlePrice': '0.18944491', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DOGEUSDT
# 0.01
#
# {'symbol': 'RLCUSDT', 'markPrice': '2.75820000', 'indexPrice': '2.75848083', 'estimatedSettlePrice': '2.75595316', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RLCUSDT
# 0.01
#
# {'symbol': 'TRXUSDT', 'markPrice': '0.06811755', 'indexPrice': '0.06814535', 'estimatedSettlePrice': '0.06810689', 'lastFundingRate': '-0.00005287', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# TRXUSDT
# -0.005287
#
# {'symbol': 'BTCSTUSDT', 'markPrice': '20.93911955', 'indexPrice': '20.93911955', 'estimatedSettlePrice': '20.95794200', 'lastFundingRate': '0', 'interestRate': '0', 'nextFundingTime': '0', 'time': '1642230729005'}
# BTCSTUSDT
# 0.0
#
# {'symbol': 'STORJUSDT', 'markPrice': '1.60180000', 'indexPrice': '1.60420160', 'estimatedSettlePrice': '1.60361990', 'lastFundingRate': '0.00003886', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# STORJUSDT
# 0.0038859999999999997
#
# {'symbol': 'SNXUSDT', 'markPrice': '5.32800000', 'indexPrice': '5.32849860', 'estimatedSettlePrice': '5.34329314', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SNXUSDT
# 0.01
#
# {'symbol': '1000XECUSDT', 'markPrice': '0.09923224', 'indexPrice': '0.09927176', 'estimatedSettlePrice': '0.09925285', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# 1000XECUSDT
# 0.01
#
# {'symbol': 'AUDIOUSDT', 'markPrice': '1.45200000', 'indexPrice': '1.45220238', 'estimatedSettlePrice': '1.45409623', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# AUDIOUSDT
# 0.01
#
# {'symbol': 'XLMUSDT', 'markPrice': '0.26096000', 'indexPrice': '0.26106855', 'estimatedSettlePrice': '0.26101756', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XLMUSDT
# 0.01
#
# {'symbol': 'IOTXUSDT', 'markPrice': '0.10220395', 'indexPrice': '0.10220294', 'estimatedSettlePrice': '0.10215715', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# IOTXUSDT
# 0.01
#
# {'symbol': 'NEOUSDT', 'markPrice': '25.61964339', 'indexPrice': '25.63455978', 'estimatedSettlePrice': '25.47968721', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# NEOUSDT
# 0.01
#
# {'symbol': 'UNFIUSDT', 'markPrice': '7.72300000', 'indexPrice': '7.72568379', 'estimatedSettlePrice': '7.73797460', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# UNFIUSDT
# 0.01
#
# {'symbol': 'SANDUSDT', 'markPrice': '4.81107638', 'indexPrice': '4.81519349', 'estimatedSettlePrice': '4.81980801', 'lastFundingRate': '0.00009428', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SANDUSDT
# 0.009428
#
# {'symbol': 'DASHUSDT', 'markPrice': '141.47129328', 'indexPrice': '141.48434489', 'estimatedSettlePrice': '141.46739216', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DASHUSDT
# 0.01
#
# {'symbol': 'KAVAUSDT', 'markPrice': '5.47650000', 'indexPrice': '5.47692108', 'estimatedSettlePrice': '5.49091417', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# KAVAUSDT
# 0.01
#
# {'symbol': 'RUNEUSDT', 'markPrice': '6.37070679', 'indexPrice': '6.37641626', 'estimatedSettlePrice': '6.37773054', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RUNEUSDT
# 0.01
#
# {'symbol': 'CTKUSDT', 'markPrice': '1.51000000', 'indexPrice': '1.51019080', 'estimatedSettlePrice': '1.50950414', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CTKUSDT
# 0.01
#
# {'symbol': 'LINKUSDT', 'markPrice': '25.67744554', 'indexPrice': '25.67718957', 'estimatedSettlePrice': '25.73592839', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LINKUSDT
# 0.01
#
# {'symbol': 'CELRUSDT', 'markPrice': '0.08882959', 'indexPrice': '0.08885953', 'estimatedSettlePrice': '0.08879945', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CELRUSDT
# 0.01
#
# {'symbol': 'RSRUSDT', 'markPrice': '0.02615300', 'indexPrice': '0.02616990', 'estimatedSettlePrice': '0.02618832', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RSRUSDT
# 0.01
#
# {'symbol': 'ADABUSD', 'markPrice': '1.26500000', 'indexPrice': '1.26519220', 'estimatedSettlePrice': '1.26818030', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ADABUSD
# 0.01
#
# {'symbol': 'DGBUSDT', 'markPrice': '0.03023000', 'indexPrice': '0.03027482', 'estimatedSettlePrice': '0.03023592', 'lastFundingRate': '-0.00030202', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DGBUSDT
# -0.030202
#
# {'symbol': 'SKLUSDT', 'markPrice': '0.17645000', 'indexPrice': '0.17654131', 'estimatedSettlePrice': '0.17663546', 'lastFundingRate': '-0.00041794', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SKLUSDT
# -0.041794
#
# {'symbol': 'RENUSDT', 'markPrice': '0.46570000', 'indexPrice': '0.46601682', 'estimatedSettlePrice': '0.46618122', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RENUSDT
# 0.01
#
# {'symbol': 'LPTUSDT', 'markPrice': '36.24430889', 'indexPrice': '36.24394758', 'estimatedSettlePrice': '36.21532692', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LPTUSDT
# 0.01
#
# {'symbol': 'TOMOUSDT', 'markPrice': '1.53190000', 'indexPrice': '1.53250246', 'estimatedSettlePrice': '1.53315652', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# TOMOUSDT
# 0.01
#
# {'symbol': 'MTLUSDT', 'markPrice': '1.85841564', 'indexPrice': '1.85921344', 'estimatedSettlePrice': '1.85947297', 'lastFundingRate': '-0.00008166', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# MTLUSDT
# -0.008166
#
# {'symbol': 'LTCUSDT', 'markPrice': '149.15571956', 'indexPrice': '149.25319397', 'estimatedSettlePrice': '148.90626619', 'lastFundingRate': '-0.00000313', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LTCUSDT
# -0.000313
#
# {'symbol': 'DODOUSDT', 'markPrice': '0.80287776', 'indexPrice': '0.80327767', 'estimatedSettlePrice': '0.80193046', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DODOUSDT
# 0.01
#
# {'symbol': 'KSMUSDT', 'markPrice': '283.60000000', 'indexPrice': '283.80095906', 'estimatedSettlePrice': '284.09556978', 'lastFundingRate': '0.00008776', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# KSMUSDT
# 0.008776
#
# {'symbol': 'EGLDUSDT', 'markPrice': '199.61756298', 'indexPrice': '199.61557306', 'estimatedSettlePrice': '199.53747797', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# EGLDUSDT
# 0.01
#
# {'symbol': 'BNBBUSD', 'markPrice': '493.98830522', 'indexPrice': '494.59367753', 'estimatedSettlePrice': '494.36425102', 'lastFundingRate': '-0.00068414', 'interestRate': '0', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BNBBUSD
# -0.068414
#
# {'symbol': 'VETUSDT', 'markPrice': '0.07869120', 'indexPrice': '0.07872272', 'estimatedSettlePrice': '0.07864387', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# VETUSDT
# 0.01
#
# {'symbol': 'ONTUSDT', 'markPrice': '0.63870000', 'indexPrice': '0.63876877', 'estimatedSettlePrice': '0.63417543', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ONTUSDT
# 0.01
#
# {'symbol': 'TRBUSDT', 'markPrice': '29.61166945', 'indexPrice': '29.61137426', 'estimatedSettlePrice': '29.64420126', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# TRBUSDT
# 0.01
#
# {'symbol': 'MANAUSDT', 'markPrice': '2.94023317', 'indexPrice': '2.94091006', 'estimatedSettlePrice': '2.94306622', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# MANAUSDT
# 0.01
#
# {'symbol': 'COTIUSDT', 'markPrice': '0.33310000', 'indexPrice': '0.33310990', 'estimatedSettlePrice': '0.33315804', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# COTIUSDT
# 0.01
#
# {'symbol': 'CHRUSDT', 'markPrice': '0.83110000', 'indexPrice': '0.83116877', 'estimatedSettlePrice': '0.83248897', 'lastFundingRate': '-0.00013585', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CHRUSDT
# -0.013585
#
# {'symbol': 'BAKEUSDT', 'markPrice': '0.99234465', 'indexPrice': '0.99233476', 'estimatedSettlePrice': '0.99285807', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BAKEUSDT
# 0.01
#
# {'symbol': 'GRTUSDT', 'markPrice': '0.57647000', 'indexPrice': '0.57662737', 'estimatedSettlePrice': '0.57656487', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# GRTUSDT
# 0.01
#
# {'symbol': 'ETHUSDT_220325', 'markPrice': '3362.47037442', 'indexPrice': '3314.76546738', 'estimatedSettlePrice': '3316.02289147', 'lastFundingRate': '0', 'interestRate': '0', 'nextFundingTime': '0', 'time': '1642230729005'}
# ETHUSDT_220325
# 0.0
#
# {'symbol': 'FLMUSDT', 'markPrice': '0.34200000', 'indexPrice': '0.34221818', 'estimatedSettlePrice': '0.34103075', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# FLMUSDT
# 0.01
#
# {'symbol': 'MASKUSDT', 'markPrice': '9.52710076', 'indexPrice': '9.53092861', 'estimatedSettlePrice': '9.53780158', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# MASKUSDT
# 0.01
#
# {'symbol': 'EOSUSDT', 'markPrice': '2.91000000', 'indexPrice': '2.91087335', 'estimatedSettlePrice': '2.88650502', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# EOSUSDT
# 0.01
#
# {'symbol': 'OGNUSDT', 'markPrice': '0.52450000', 'indexPrice': '0.52450959', 'estimatedSettlePrice': '0.52326069', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# OGNUSDT
# 0.01
#
# {'symbol': 'SCUSDT', 'markPrice': '0.01385300', 'indexPrice': '0.01385655', 'estimatedSettlePrice': '0.01385478', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SCUSDT
# 0.01
#
# {'symbol': 'BALUSDT', 'markPrice': '17.35795207', 'indexPrice': '17.38498683', 'estimatedSettlePrice': '17.39196504', 'lastFundingRate': '-0.00091163', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BALUSDT
# -0.091163
#
# {'symbol': 'STMXUSDT', 'markPrice': '0.01864666', 'indexPrice': '0.01864836', 'estimatedSettlePrice': '0.01865829', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# STMXUSDT
# 0.01
#
# {'symbol': 'BTTUSDT', 'markPrice': '0.00251396', 'indexPrice': '0.00251394', 'estimatedSettlePrice': '0.00251368', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BTTUSDT
# 0.01
#
# {'symbol': 'LUNAUSDT', 'markPrice': '81.80181806', 'indexPrice': '81.85855434', 'estimatedSettlePrice': '81.95643437', 'lastFundingRate': '-0.00008443', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LUNAUSDT
# -0.008443
#
# {'symbol': 'DENTUSDT', 'markPrice': '0.00369497', 'indexPrice': '0.00369494', 'estimatedSettlePrice': '0.00369514', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DENTUSDT
# 0.01
#
# {'symbol': 'KNCUSDT', 'markPrice': '1.43200000', 'indexPrice': '1.43223133', 'estimatedSettlePrice': '1.43226341', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# KNCUSDT
# 0.01
#
# {'symbol': 'SRMUSDT', 'markPrice': '3.18400000', 'indexPrice': '3.18599314', 'estimatedSettlePrice': '3.18936312', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SRMUSDT
# 0.01
#
# {'symbol': 'ENJUSDT', 'markPrice': '2.37730000', 'indexPrice': '2.37812309', 'estimatedSettlePrice': '2.38087754', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ENJUSDT
# 0.01
#
# {'symbol': 'C98USDT', 'markPrice': '2.45595519', 'indexPrice': '2.45593879', 'estimatedSettlePrice': '2.46111702', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# C98USDT
# 0.01
#
# {'symbol': 'ZENUSDT', 'markPrice': '54.24328429', 'indexPrice': '54.25546822', 'estimatedSettlePrice': '54.15415898', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ZENUSDT
# 0.01
#
# {'symbol': 'ATOMUSDT', 'markPrice': '40.03072845', 'indexPrice': '40.03032939', 'estimatedSettlePrice': '40.13983166', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ATOMUSDT
# 0.01
#
# {'symbol': 'NEARUSDT', 'markPrice': '19.41850000', 'indexPrice': '19.43022284', 'estimatedSettlePrice': '19.44990741', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# NEARUSDT
# 0.01
#
# {'symbol': 'SOLBUSD', 'markPrice': '145.58720454', 'indexPrice': '145.63063293', 'estimatedSettlePrice': '145.68825153', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SOLBUSD
# 0.01
#
# {'symbol': 'ENSUSDT', 'markPrice': '27.12275750', 'indexPrice': '27.12248712', 'estimatedSettlePrice': '27.07072344', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ENSUSDT
# 0.01
#
# {'symbol': 'BCHUSDT', 'markPrice': '388.80000000', 'indexPrice': '389.00745167', 'estimatedSettlePrice': '388.94102471', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BCHUSDT
# 0.01
#
# {'symbol': 'ATAUSDT', 'markPrice': '0.56400000', 'indexPrice': '0.56405011', 'estimatedSettlePrice': '0.56367883', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ATAUSDT
# 0.01
#
# {'symbol': 'IOSTUSDT', 'markPrice': '0.02963807', 'indexPrice': '0.02963778', 'estimatedSettlePrice': '0.02958521', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# IOSTUSDT
# 0.01
#
# {'symbol': 'HBARUSDT', 'markPrice': '0.28019014', 'indexPrice': '0.28031957', 'estimatedSettlePrice': '0.28015540', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# HBARUSDT
# 0.01
#
# {'symbol': 'ZECUSDT', 'markPrice': '143.28384023', 'indexPrice': '143.32171821', 'estimatedSettlePrice': '143.40532456', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ZECUSDT
# 0.01
#
# {'symbol': '1000SHIBUSDT', 'markPrice': '0.03092200', 'indexPrice': '0.03092911', 'estimatedSettlePrice': '0.03084897', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# 1000SHIBUSDT
# 0.01
#
# {'symbol': 'TLMUSDT', 'markPrice': '0.17292087', 'indexPrice': '0.17297754', 'estimatedSettlePrice': '0.17304881', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# TLMUSDT
# 0.01
#
# {'symbol': 'ANTUSDT', 'markPrice': '8.52906244', 'indexPrice': '8.52897742', 'estimatedSettlePrice': '8.54688412', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ANTUSDT
# 0.01
#
# {'symbol': 'ETHBUSD', 'markPrice': '3314.94093809', 'indexPrice': '3316.45564882', 'estimatedSettlePrice': '3317.46414776', 'lastFundingRate': '0.00007918', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ETHBUSD
# 0.007918
#
# {'symbol': 'GALAUSDT', 'markPrice': '0.32973408', 'indexPrice': '0.32982138', 'estimatedSettlePrice': '0.33011215', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# GALAUSDT
# 0.01
#
# {'symbol': 'AAVEUSDT', 'markPrice': '229.36000000', 'indexPrice': '229.40381052', 'estimatedSettlePrice': '230.15214352', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# AAVEUSDT
# 0.01
#
# {'symbol': 'GTCUSDT', 'markPrice': '11.33833472', 'indexPrice': '11.33822170', 'estimatedSettlePrice': '11.33335645', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# GTCUSDT
# 0.01
#
# {'symbol': 'ALGOUSDT', 'markPrice': '1.37770000', 'indexPrice': '1.37773220', 'estimatedSettlePrice': '1.37738784', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ALGOUSDT
# 0.01
#
# {'symbol': 'ICPUSDT', 'markPrice': '32.13596462', 'indexPrice': '32.13564427', 'estimatedSettlePrice': '32.12229553', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ICPUSDT
# 0.01
#
# {'symbol': 'LRCUSDT', 'markPrice': '1.42363773', 'indexPrice': '1.42417606', 'estimatedSettlePrice': '1.42343880', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LRCUSDT
# 0.01
#
# {'symbol': 'AVAXUSDT', 'markPrice': '89.98100000', 'indexPrice': '89.99676839', 'estimatedSettlePrice': '90.16010938', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# AVAXUSDT
# 0.01
#
# {'symbol': 'BTCUSDT_220325', 'markPrice': '43650.07222423', 'indexPrice': '43023.23061397', 'estimatedSettlePrice': '43038.48989376', 'lastFundingRate': '0', 'interestRate': '0', 'nextFundingTime': '0', 'time': '1642230729005'}
# BTCUSDT_220325
# 0.0
#
# {'symbol': 'ARPAUSDT', 'markPrice': '0.08540186', 'indexPrice': '0.08547753', 'estimatedSettlePrice': '0.08554460', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ARPAUSDT
# 0.01
#
# {'symbol': 'CELOUSDT', 'markPrice': '5.06995052', 'indexPrice': '5.06994042', 'estimatedSettlePrice': '5.07929611', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CELOUSDT
# 0.01
#
# {'symbol': 'ROSEUSDT', 'markPrice': '0.59241238', 'indexPrice': '0.59418371', 'estimatedSettlePrice': '0.59130544', 'lastFundingRate': '-0.00305779', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ROSEUSDT
# -0.30577899999999997
#
# {'symbol': 'MATICUSDT', 'markPrice': '2.33323004', 'indexPrice': '2.33322145', 'estimatedSettlePrice': '2.33783764', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# MATICUSDT
# 0.01
#
# {'symbol': '1INCHUSDT', 'markPrice': '2.36000000', 'indexPrice': '2.36141027', 'estimatedSettlePrice': '2.36312218', 'lastFundingRate': '0.00005946', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# 1INCHUSDT
# 0.005946
#
# {'symbol': 'MKRUSDT', 'markPrice': '2190.71379232', 'indexPrice': '2191.29597030', 'estimatedSettlePrice': '2191.83064967', 'lastFundingRate': '0.00000850', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# MKRUSDT
# 0.00085
#
# {'symbol': 'PEOPLEUSDT', 'markPrice': '0.07805000', 'indexPrice': '0.07808117', 'estimatedSettlePrice': '0.07821186', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# PEOPLEUSDT
# 0.01
#
# {'symbol': 'THETAUSDT', 'markPrice': '4.09400000', 'indexPrice': '4.09508364', 'estimatedSettlePrice': '4.09432927', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# THETAUSDT
# 0.01
#
# {'symbol': 'UNIUSDT', 'markPrice': '16.31361538', 'indexPrice': '16.31853331', 'estimatedSettlePrice': '16.33723855', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# UNIUSDT
# 0.01
#
# {'symbol': 'LINAUSDT', 'markPrice': '0.03612573', 'indexPrice': '0.03615299', 'estimatedSettlePrice': '0.03616121', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# LINAUSDT
# 0.01
#
# {'symbol': 'ARUSDT', 'markPrice': '50.59590475', 'indexPrice': '50.59540038', 'estimatedSettlePrice': '50.55985955', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ARUSDT
# 0.01
#
# {'symbol': 'RVNUSDT', 'markPrice': '0.09996527', 'indexPrice': '0.09996428', 'estimatedSettlePrice': '0.10014961', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# RVNUSDT
# 0.01
#
# {'symbol': 'FILUSDT', 'markPrice': '30.14636599', 'indexPrice': '30.14606547', 'estimatedSettlePrice': '29.99511691', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# FILUSDT
# 0.01
#
# {'symbol': 'NKNUSDT', 'markPrice': '0.29291933', 'indexPrice': '0.29292026', 'estimatedSettlePrice': '0.29286371', 'lastFundingRate': '0.00008656', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# NKNUSDT
# 0.008656
#
# {'symbol': 'KLAYUSDT', 'markPrice': '1.37489313', 'indexPrice': '1.37636513', 'estimatedSettlePrice': '1.37284385', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# KLAYUSDT
# 0.01
#
# {'symbol': 'DEFIUSDT', 'markPrice': '2374', 'indexPrice': '2374.97305278', 'estimatedSettlePrice': '2377.51841116', 'lastFundingRate': '0.00000224', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DEFIUSDT
# 0.00022400000000000002
#
# {'symbol': 'COMPUSDT', 'markPrice': '193.46853114', 'indexPrice': '193.61621765', 'estimatedSettlePrice': '193.16850227', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# COMPUSDT
# 0.01
#
# {'symbol': 'BTCDOMUSDT', 'markPrice': '1049.96472971', 'indexPrice': '1049.83732384', 'estimatedSettlePrice': '1050.25965453', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BTCDOMUSDT
# 0.01
#
# {'symbol': 'SOLUSDT', 'markPrice': '145.58000000', 'indexPrice': '145.58649484', 'estimatedSettlePrice': '145.63187869', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SOLUSDT
# 0.01
#
# {'symbol': 'BTCUSDT', 'markPrice': '43009.71000000', 'indexPrice': '43023.23061397', 'estimatedSettlePrice': '43038.48989376', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BTCUSDT
# 0.01
#
# {'symbol': 'OMGUSDT', 'markPrice': '6.34967855', 'indexPrice': '6.35245701', 'estimatedSettlePrice': '6.38443412', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# OMGUSDT
# 0.01
#
# {'symbol': 'ICXUSDT', 'markPrice': '1.05324896', 'indexPrice': '1.05463498', 'estimatedSettlePrice': '1.05251420', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ICXUSDT
# 0.01
#
# {'symbol': 'BLZUSDT', 'markPrice': '0.18458584', 'indexPrice': '0.18454779', 'estimatedSettlePrice': '0.18451426', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BLZUSDT
# 0.01
#
# {'symbol': 'FTMUSDT', 'markPrice': '2.88720000', 'indexPrice': '2.88767924', 'estimatedSettlePrice': '2.89866652', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# FTMUSDT
# 0.01
#
# {'symbol': 'YFIIUSDT', 'markPrice': '2617.40000000', 'indexPrice': '2618.12673783', 'estimatedSettlePrice': '2621.74693457', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# YFIIUSDT
# 0.01
#
# {'symbol': 'KEEPUSDT', 'markPrice': '0.64943012', 'indexPrice': '0.64993904', 'estimatedSettlePrice': '0.65031331', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# KEEPUSDT
# 0.01
#
# {'symbol': 'BANDUSDT', 'markPrice': '5.66172840', 'indexPrice': '5.66437013', 'estimatedSettlePrice': '5.66458633', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BANDUSDT
# 0.01
#
# {'symbol': 'XRPBUSD', 'markPrice': '0.77776252', 'indexPrice': '0.77738319', 'estimatedSettlePrice': '0.77674372', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XRPBUSD
# 0.01
#
# {'symbol': 'DOGEBUSD', 'markPrice': '0.19218000', 'indexPrice': '0.19226397', 'estimatedSettlePrice': '0.18954575', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DOGEBUSD
# 0.01
#
# {'symbol': 'XRPUSDT', 'markPrice': '0.77758659', 'indexPrice': '0.77791441', 'estimatedSettlePrice': '0.77712022', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XRPUSDT
# 0.01
#
# {'symbol': 'SXPUSDT', 'markPrice': '1.81660000', 'indexPrice': '1.81766413', 'estimatedSettlePrice': '1.82620945', 'lastFundingRate': '-0.00021850', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# SXPUSDT
# -0.02185
#
# {'symbol': 'CRVUSDT', 'markPrice': '5.31200000', 'indexPrice': '5.31713126', 'estimatedSettlePrice': '5.33543918', 'lastFundingRate': '-0.00030270', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CRVUSDT
# -0.03027
#
# {'symbol': 'BELUSDT', 'markPrice': '1.32477804', 'indexPrice': '1.32487688', 'estimatedSettlePrice': '1.32458166', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# BELUSDT
# 0.01
#
# {'symbol': 'DOTUSDT', 'markPrice': '27.22200000', 'indexPrice': '27.23915674', 'estimatedSettlePrice': '27.25991208', 'lastFundingRate': '0.00002248', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DOTUSDT
# 0.002248
#
# {'symbol': 'XEMUSDT', 'markPrice': '0.11923981', 'indexPrice': '0.11933330', 'estimatedSettlePrice': '0.11928149', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# XEMUSDT
# 0.01
#
# {'symbol': 'ONEUSDT', 'markPrice': '0.34828000', 'indexPrice': '0.34836292', 'estimatedSettlePrice': '0.34703817', 'lastFundingRate': '0.00000067', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ONEUSDT
# 6.7e-05
#
# {'symbol': 'ZILUSDT', 'markPrice': '0.06400684', 'indexPrice': '0.06402280', 'estimatedSettlePrice': '0.06397518', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ZILUSDT
# 0.01
#
# {'symbol': 'AXSUSDT', 'markPrice': '74.40000000', 'indexPrice': '74.46951384', 'estimatedSettlePrice': '74.55029013', 'lastFundingRate': '-0.00065927', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# AXSUSDT
# -0.065927
#
# {'symbol': 'DYDXUSDT', 'markPrice': '7.70418588', 'indexPrice': '7.71214872', 'estimatedSettlePrice': '7.70970963', 'lastFundingRate': '-0.00006924', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DYDXUSDT
# -0.006924
#
# {'symbol': 'OCEANUSDT', 'markPrice': '0.79826000', 'indexPrice': '0.79856672', 'estimatedSettlePrice': '0.79846350', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# OCEANUSDT
# 0.01
#
# {'symbol': 'CHZUSDT', 'markPrice': '0.26566000', 'indexPrice': '0.26577362', 'estimatedSettlePrice': '0.26592861', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CHZUSDT
# 0.01
#
# {'symbol': 'ANKRUSDT', 'markPrice': '0.09278000', 'indexPrice': '0.09288112', 'estimatedSettlePrice': '0.09285760', 'lastFundingRate': '0.00006530', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# ANKRUSDT
# 0.00653
#
# {'symbol': 'DUSKUSDT', 'markPrice': '0.92079694', 'indexPrice': '0.92182887', 'estimatedSettlePrice': '0.92621258', 'lastFundingRate': '-0.00006643', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# DUSKUSDT
# -0.006643
#
# {'symbol': 'CTSIUSDT', 'markPrice': '0.71067408', 'indexPrice': '0.71066700', 'estimatedSettlePrice': '0.71047565', 'lastFundingRate': '0.00010000', 'interestRate': '0.00010000', 'nextFundingTime': '1642233600000', 'time': '1642230729005'}
# CTSIUSDT
# 0.01
