# %%
import ccxt
import pandas as pd
import os
import csv

# %%
exchange = ccxt.okex({
    'enableRateLimit': True,
})
Response = exchange.load_markets()
Keys_List = ['Symbol','Pair','Base','Quote','Type']

# %%
USD_USDT_Symbol_List  = []
for i in Response:
    Currency_Dict = Response[i]
    if Currency_Dict['swap']==True:
        if Currency_Dict['quote'] == 'USDT' or Currency_Dict['quote']=='USD':
            Symbol_List = []
            Symbol_List.append(Currency_Dict['base']+Currency_Dict['quote'])
            Symbol_List.append(Currency_Dict['symbol'])
            Symbol_List.append(Currency_Dict['base'])
            Symbol_List.append(Currency_Dict['quote'])
            Symbol_List.append(Currency_Dict['quote']+'-PERP')
            USD_USDT_Symbol_List.append(Symbol_List)

# %%
def Data_To_List(Currency_List,Keys_Values_List):
    Full_List = []
    for i in range(len(Currency_List)):
        Def_Symbol_List = []
        for x in range(len(Keys_Values_List)):
            Def_Symbol_List.append( [Keys_Values_List[x],Currency_List[i][x]] )
        Full_List.append(Def_Symbol_List)
    return(Full_List)

# %%
USD_USDT_Data_List  = Data_To_List(USD_USDT_Symbol_List,Keys_List)

# %%
def Csv_Function(exchange_name,currency_list):
    for i in range(len(currency_list)):
        
        Store_Path = os.getcwd() + '\\' + currency_list[i][4][1]
        if os.path.exists(Store_Path) == True:
            
            File_Path = Store_Path + '\\' + currency_list[i][0][1] + "-" + currency_list[i][4][1]
            
            write_value = exchange_name + '/' + str(currency_list[i])
            
            if os.path.exists(File_Path) == False:
                with open(File_Path, 'a', newline='') as csv_write:
                    writer = csv.writer(csv_write, delimiter=',')
                    writer.writerow([write_value])
                    print(write_value)
                    
            
            if os.path.exists(File_Path) == True:
                with open(File_Path, 'r', newline='') as csv_read:
                    rows = list(csv.reader(csv_read))
                    if [write_value] not in rows:
                        with open(File_Path, 'a', newline='') as csv_write:
                                writer = csv.writer(csv_write, delimiter=',')
                                writer.writerow([write_value])
                                print(write_value)
                                print(rows)

# %%
Csv_Function('okex',USD_USDT_Data_List)
# Out:
# okex/[['Symbol', 'BTCUSD'], ['Pair', 'BTC/USD:BTC'], ['Base', 'BTC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'BTCUSD'], ['Pair', 'BTCUSD_PERP'], ['Base', 'BTC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'ETHUSD'], ['Pair', 'ETH/USD:ETH'], ['Base', 'ETH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'ETHUSD'], ['Pair', 'ETHUSD_PERP'], ['Base', 'ETH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'LTCUSD'], ['Pair', 'LTC/USD:LTC'], ['Base', 'LTC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'LTCUSD'], ['Pair', 'LTCUSD_PERP'], ['Base', 'LTC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'DOTUSD'], ['Pair', 'DOT/USD:DOT'], ['Base', 'DOT'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'DOTUSD'], ['Pair', 'DOTUSD_PERP'], ['Base', 'DOT'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'DOGEUSD'], ['Pair', 'DOGE/USD:DOGE'], ['Base', 'DOGE'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'DOGEUSD'], ['Pair', 'DOGEUSD_PERP'], ['Base', 'DOGE'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'ADAUSD'], ['Pair', 'ADA/USD:ADA'], ['Base', 'ADA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'ADAUSD'], ['Pair', 'ADAUSD_PERP'], ['Base', 'ADA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'ATOMUSD'], ['Pair', 'ATOM/USD:ATOM'], ['Base', 'ATOM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'ATOMUSD'], ['Pair', 'ATOMUSD_PERP'], ['Base', 'ATOM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', '1INCHUSD'], ['Pair', '1INCH/USD:1INCH'], ['Base', '1INCH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'ALGOUSD'], ['Pair', 'ALGO/USD:ALGO'], ['Base', 'ALGO'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'AVAXUSD'], ['Pair', 'AVAX/USD:AVAX'], ['Base', 'AVAX'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'AVAXUSD'], ['Pair', 'AVAXUSD_PERP'], ['Base', 'AVAX'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'BCHUSD'], ['Pair', 'BCH/USD:BCH'], ['Base', 'BCH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'BCHUSD'], ['Pair', 'BCHUSD_PERP'], ['Base', 'BCH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'BSVUSD'], ['Pair', 'BSV/USD:BSV'], ['Base', 'BSV'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'CRVUSD'], ['Pair', 'CRV/USD:CRV'], ['Base', 'CRV'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'CRVUSD'], ['Pair', 'CRVUSD_PERP'], ['Base', 'CRV'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'DASHUSD'], ['Pair', 'DASH/USD:DASH'], ['Base', 'DASH'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'EOSUSD'], ['Pair', 'EOS/USD:EOS'], ['Base', 'EOS'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'EOSUSD'], ['Pair', 'EOSUSD_PERP'], ['Base', 'EOS'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'ETCUSD'], ['Pair', 'ETC/USD:ETC'], ['Base', 'ETC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'ETCUSD'], ['Pair', 'ETCUSD_PERP'], ['Base', 'ETC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'FILUSD'], ['Pair', 'FIL/USD:FIL'], ['Base', 'FIL'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'FILUSD'], ['Pair', 'FILUSD_PERP'], ['Base', 'FIL'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'GRTUSD'], ['Pair', 'GRT/USD:GRT'], ['Base', 'GRT'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'IOSTUSD'], ['Pair', 'IOST/USD:IOST'], ['Base', 'IOST'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'IOTAUSD'], ['Pair', 'IOTA/USD:IOTA'], ['Base', 'IOTA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'KNCUSD'], ['Pair', 'KNC/USD:KNC'], ['Base', 'KNC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'KSMUSD'], ['Pair', 'KSM/USD:KSM'], ['Base', 'KSM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'LINKUSD'], ['Pair', 'LINK/USD:LINK'], ['Base', 'LINK'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'LINKUSD'], ['Pair', 'LINKUSD_PERP'], ['Base', 'LINK'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'MANAUSD'], ['Pair', 'MANA/USD:MANA'], ['Base', 'MANA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'MANAUSD'], ['Pair', 'MANAUSD_PERP'], ['Base', 'MANA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'NEOUSD'], ['Pair', 'NEO/USD:NEO'], ['Base', 'NEO'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'ONTUSD'], ['Pair', 'ONT/USD:ONT'], ['Base', 'ONT'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'QTUMUSD'], ['Pair', 'QTUM/USD:QTUM'], ['Base', 'QTUM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'SANDUSD'], ['Pair', 'SAND/USD:SAND'], ['Base', 'SAND'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'SANDUSD'], ['Pair', 'SANDUSD_PERP'], ['Base', 'SAND'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'SOLUSD'], ['Pair', 'SOL/USD:SOL'], ['Base', 'SOL'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'SOLUSD'], ['Pair', 'SOLUSD_PERP'], ['Base', 'SOL'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'SUSHIUSD'], ['Pair', 'SUSHI/USD:SUSHI'], ['Base', 'SUSHI'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'THETAUSD'], ['Pair', 'THETA/USD:THETA'], ['Base', 'THETA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'THETAUSD'], ['Pair', 'THETAUSD_PERP'], ['Base', 'THETA'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'TRXUSD'], ['Pair', 'TRX/USD:TRX'], ['Base', 'TRX'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'TRXUSD'], ['Pair', 'TRXUSD_PERP'], ['Base', 'TRX'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'UNIUSD'], ['Pair', 'UNI/USD:UNI'], ['Base', 'UNI'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'UNIUSD'], ['Pair', 'UNIUSD_PERP'], ['Base', 'UNI'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'XLMUSD'], ['Pair', 'XLM/USD:XLM'], ['Base', 'XLM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'XLMUSD'], ['Pair', 'XLMUSD_PERP'], ['Base', 'XLM'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'XMRUSD'], ['Pair', 'XMR/USD:XMR'], ['Base', 'XMR'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'XRPUSD'], ['Pair', 'XRP/USD:XRP'], ['Base', 'XRP'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# [["binance/[['Symbol', 'XRPUSD'], ['Pair', 'XRPUSD_PERP'], ['Base', 'XRP'], ['Quote', 'USD'], ['Type', 'USD-PERP']]"]]
# okex/[['Symbol', 'XTZUSD'], ['Pair', 'XTZ/USD:XTZ'], ['Base', 'XTZ'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'YFIUSD'], ['Pair', 'YFI/USD:YFI'], ['Base', 'YFI'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'YFIIUSD'], ['Pair', 'YFII/USD:YFII'], ['Base', 'YFII'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'ZECUSD'], ['Pair', 'ZEC/USD:ZEC'], ['Base', 'ZEC'], ['Quote', 'USD'], ['Type', 'USD-PERP']]
# okex/[['Symbol', 'BTCUSDT'], ['Pair', 'BTC/USDT:USDT'], ['Base', 'BTC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'BTCUSDT'], ['Pair', 'BTCUSDT'], ['Base', 'BTC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ETHUSDT'], ['Pair', 'ETH/USDT:USDT'], ['Base', 'ETH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ETHUSDT'], ['Pair', 'ETHUSDT'], ['Base', 'ETH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'DOTUSDT'], ['Pair', 'DOT/USDT:USDT'], ['Base', 'DOT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'DOTUSDT'], ['Pair', 'DOTUSDT'], ['Base', 'DOT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'LTCUSDT'], ['Pair', 'LTC/USDT:USDT'], ['Base', 'LTC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'LTCUSDT'], ['Pair', 'LTCUSDT'], ['Base', 'LTC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'DOGEUSDT'], ['Pair', 'DOGE/USDT:USDT'], ['Base', 'DOGE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'DOGEUSDT'], ['Pair', 'DOGEUSDT'], ['Base', 'DOGE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ADAUSDT'], ['Pair', 'ADA/USDT:USDT'], ['Base', 'ADA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ADAUSDT'], ['Pair', 'ADAUSDT'], ['Base', 'ADA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ATOMUSDT'], ['Pair', 'ATOM/USDT:USDT'], ['Base', 'ATOM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ATOMUSDT'], ['Pair', 'ATOMUSDT'], ['Base', 'ATOM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'LUNAUSDT'], ['Pair', 'LUNA/USDT:USDT'], ['Base', 'LUNA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'LUNAUSDT'], ['Pair', 'LUNAUSDT'], ['Base', 'LUNA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'FTMUSDT'], ['Pair', 'FTM/USDT:USDT'], ['Base', 'FTM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'FTMUSDT'], ['Pair', 'FTMUSDT'], ['Base', 'FTM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'NEARUSDT'], ['Pair', 'NEAR/USDT:USDT'], ['Base', 'NEAR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'NEARUSDT'], ['Pair', 'NEARUSDT'], ['Base', 'NEAR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', '1INCHUSDT'], ['Pair', '1INCH/USDT:USDT'], ['Base', '1INCH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', '1INCHUSDT'], ['Pair', '1INCHUSDT'], ['Base', '1INCH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'AAVEUSDT'], ['Pair', 'AAVE/USDT:USDT'], ['Base', 'AAVE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'AAVEUSDT'], ['Pair', 'AAVEUSDT'], ['Base', 'AAVE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'AGLDUSDT'], ['Pair', 'AGLD/USDT:USDT'], ['Base', 'AGLD'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'ALGOUSDT'], ['Pair', 'ALGO/USDT:USDT'], ['Base', 'ALGO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ALGOUSDT'], ['Pair', 'ALGOUSDT'], ['Base', 'ALGO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ALPHAUSDT'], ['Pair', 'ALPHA/USDT:USDT'], ['Base', 'ALPHA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ALPHAUSDT'], ['Pair', 'ALPHAUSDT'], ['Base', 'ALPHA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ANCUSDT'], ['Pair', 'ANC/USDT:USDT'], ['Base', 'ANC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'ANTUSDT'], ['Pair', 'ANT/USDT:USDT'], ['Base', 'ANT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ANTUSDT'], ['Pair', 'ANTUSDT'], ['Base', 'ANT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'AVAXUSDT'], ['Pair', 'AVAX/USDT:USDT'], ['Base', 'AVAX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'AVAXUSDT'], ['Pair', 'AVAXUSDT'], ['Base', 'AVAX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'AXSUSDT'], ['Pair', 'AXS/USDT:USDT'], ['Base', 'AXS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'AXSUSDT'], ['Pair', 'AXSUSDT'], ['Base', 'AXS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'BABYDOGEUSDT'], ['Pair', 'BABYDOGE/USDT:USDT'], ['Base', 'BABYDOGE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BADGERUSDT'], ['Pair', 'BADGER/USDT:USDT'], ['Base', 'BADGER'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BALUSDT'], ['Pair', 'BAL/USDT:USDT'], ['Base', 'BAL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'BALUSDT'], ['Pair', 'BALUSDT'], ['Base', 'BAL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'BANDUSDT'], ['Pair', 'BAND/USDT:USDT'], ['Base', 'BAND'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'BANDUSDT'], ['Pair', 'BANDUSDT'], ['Base', 'BAND'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'BATUSDT'], ['Pair', 'BAT/USDT:USDT'], ['Base', 'BAT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'BATUSDT'], ['Pair', 'BATUSDT'], ['Base', 'BAT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'BCHUSDT'], ['Pair', 'BCH/USDT:USDT'], ['Base', 'BCH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'BCHUSDT'], ['Pair', 'BCHUSDT'], ['Base', 'BCH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'BICOUSDT'], ['Pair', 'BICO/USDT:USDT'], ['Base', 'BICO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BNTUSDT'], ['Pair', 'BNT/USDT:USDT'], ['Base', 'BNT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BSVUSDT'], ['Pair', 'BSV/USDT:USDT'], ['Base', 'BSV'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BTMUSDT'], ['Pair', 'BTM/USDT:USDT'], ['Base', 'BTM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'BZZUSDT'], ['Pair', 'BZZ/USDT:USDT'], ['Base', 'BZZ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CELOUSDT'], ['Pair', 'CELO/USDT:USDT'], ['Base', 'CELO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'CELOUSDT'], ['Pair', 'CELOUSDT'], ['Base', 'CELO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'CFXUSDT'], ['Pair', 'CFX/USDT:USDT'], ['Base', 'CFX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CRVUSDT'], ['Pair', 'CRV/USDT:USDT'], ['Base', 'CRV'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'CRVUSDT'], ['Pair', 'CRVUSDT'], ['Base', 'CRV'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'CHZUSDT'], ['Pair', 'CHZ/USDT:USDT'], ['Base', 'CHZ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'CHZUSDT'], ['Pair', 'CHZUSDT'], ['Base', 'CHZ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'COMPUSDT'], ['Pair', 'COMP/USDT:USDT'], ['Base', 'COMP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'COMPUSDT'], ['Pair', 'COMPUSDT'], ['Base', 'COMP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'CONVUSDT'], ['Pair', 'CONV/USDT:USDT'], ['Base', 'CONV'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CQTUSDT'], ['Pair', 'CQT/USDT:USDT'], ['Base', 'CQT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CROUSDT'], ['Pair', 'CRO/USDT:USDT'], ['Base', 'CRO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CSPRUSDT'], ['Pair', 'CSPR/USDT:USDT'], ['Base', 'CSPR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'CVCUSDT'], ['Pair', 'CVC/USDT:USDT'], ['Base', 'CVC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'CVCUSDT'], ['Pair', 'CVCUSDT'], ['Base', 'CVC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'DASHUSDT'], ['Pair', 'DASH/USDT:USDT'], ['Base', 'DASH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'DASHUSDT'], ['Pair', 'DASHUSDT'], ['Base', 'DASH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'DORAUSDT'], ['Pair', 'DORA/USDT:USDT'], ['Base', 'DORA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'DYDXUSDT'], ['Pair', 'DYDX/USDT:USDT'], ['Base', 'DYDX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'DYDXUSDT'], ['Pair', 'DYDXUSDT'], ['Base', 'DYDX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'EFIUSDT'], ['Pair', 'EFI/USDT:USDT'], ['Base', 'EFI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'EGLDUSDT'], ['Pair', 'EGLD/USDT:USDT'], ['Base', 'EGLD'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'EGLDUSDT'], ['Pair', 'EGLDUSDT'], ['Base', 'EGLD'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ELONUSDT'], ['Pair', 'ELON/USDT:USDT'], ['Base', 'ELON'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'ENJUSDT'], ['Pair', 'ENJ/USDT:USDT'], ['Base', 'ENJ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ENJUSDT'], ['Pair', 'ENJUSDT'], ['Base', 'ENJ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ENSUSDT'], ['Pair', 'ENS/USDT:USDT'], ['Base', 'ENS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ENSUSDT'], ['Pair', 'ENSUSDT'], ['Base', 'ENS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'EOSUSDT'], ['Pair', 'EOS/USDT:USDT'], ['Base', 'EOS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'EOSUSDT'], ['Pair', 'EOSUSDT'], ['Base', 'EOS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ETCUSDT'], ['Pair', 'ETC/USDT:USDT'], ['Base', 'ETC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ETCUSDT'], ['Pair', 'ETCUSDT'], ['Base', 'ETC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'FILUSDT'], ['Pair', 'FIL/USDT:USDT'], ['Base', 'FIL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'FILUSDT'], ['Pair', 'FILUSDT'], ['Base', 'FIL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'FLMUSDT'], ['Pair', 'FLM/USDT:USDT'], ['Base', 'FLM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'FLMUSDT'], ['Pair', 'FLMUSDT'], ['Base', 'FLM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'GALAUSDT'], ['Pair', 'GALA/USDT:USDT'], ['Base', 'GALA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'GALAUSDT'], ['Pair', 'GALAUSDT'], ['Base', 'GALA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'GODSUSDT'], ['Pair', 'GODS/USDT:USDT'], ['Base', 'GODS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'GRTUSDT'], ['Pair', 'GRT/USDT:USDT'], ['Base', 'GRT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'GRTUSDT'], ['Pair', 'GRTUSDT'], ['Base', 'GRT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ICPUSDT'], ['Pair', 'ICP/USDT:USDT'], ['Base', 'ICP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ICPUSDT'], ['Pair', 'ICPUSDT'], ['Base', 'ICP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'IMXUSDT'], ['Pair', 'IMX/USDT:USDT'], ['Base', 'IMX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'IOSTUSDT'], ['Pair', 'IOST/USDT:USDT'], ['Base', 'IOST'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'IOSTUSDT'], ['Pair', 'IOSTUSDT'], ['Base', 'IOST'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'IOTAUSDT'], ['Pair', 'IOTA/USDT:USDT'], ['Base', 'IOTA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'IOTAUSDT'], ['Pair', 'IOTAUSDT'], ['Base', 'IOTA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'JSTUSDT'], ['Pair', 'JST/USDT:USDT'], ['Base', 'JST'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'KISHUUSDT'], ['Pair', 'KISHU/USDT:USDT'], ['Base', 'KISHU'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'KNCUSDT'], ['Pair', 'KNC/USDT:USDT'], ['Base', 'KNC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'KNCUSDT'], ['Pair', 'KNCUSDT'], ['Base', 'KNC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'KSMUSDT'], ['Pair', 'KSM/USDT:USDT'], ['Base', 'KSM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'KSMUSDT'], ['Pair', 'KSMUSDT'], ['Base', 'KSM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'LATUSDT'], ['Pair', 'LAT/USDT:USDT'], ['Base', 'LAT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'LINKUSDT'], ['Pair', 'LINK/USDT:USDT'], ['Base', 'LINK'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'LINKUSDT'], ['Pair', 'LINKUSDT'], ['Base', 'LINK'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'LONUSDT'], ['Pair', 'LON/USDT:USDT'], ['Base', 'LON'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'LPTUSDT'], ['Pair', 'LPT/USDT:USDT'], ['Base', 'LPT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'LPTUSDT'], ['Pair', 'LPTUSDT'], ['Base', 'LPT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'LRCUSDT'], ['Pair', 'LRC/USDT:USDT'], ['Base', 'LRC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'LRCUSDT'], ['Pair', 'LRCUSDT'], ['Base', 'LRC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'MANAUSDT'], ['Pair', 'MANA/USDT:USDT'], ['Base', 'MANA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'MANAUSDT'], ['Pair', 'MANAUSDT'], ['Base', 'MANA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'MASKUSDT'], ['Pair', 'MASK/USDT:USDT'], ['Base', 'MASK'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'MASKUSDT'], ['Pair', 'MASKUSDT'], ['Base', 'MASK'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'MATICUSDT'], ['Pair', 'MATIC/USDT:USDT'], ['Base', 'MATIC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'MATICUSDT'], ['Pair', 'MATICUSDT'], ['Base', 'MATIC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'MINAUSDT'], ['Pair', 'MINA/USDT:USDT'], ['Base', 'MINA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'MIRUSDT'], ['Pair', 'MIR/USDT:USDT'], ['Base', 'MIR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'MKRUSDT'], ['Pair', 'MKR/USDT:USDT'], ['Base', 'MKR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'MKRUSDT'], ['Pair', 'MKRUSDT'], ['Base', 'MKR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'NEOUSDT'], ['Pair', 'NEO/USDT:USDT'], ['Base', 'NEO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'NEOUSDT'], ['Pair', 'NEOUSDT'], ['Base', 'NEO'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'NFTUSDT'], ['Pair', 'NFT/USDT:USDT'], ['Base', 'NFT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'OMGUSDT'], ['Pair', 'OMG/USDT:USDT'], ['Base', 'OMG'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'OMGUSDT'], ['Pair', 'OMGUSDT'], ['Base', 'OMG'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ONTUSDT'], ['Pair', 'ONT/USDT:USDT'], ['Base', 'ONT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ONTUSDT'], ['Pair', 'ONTUSDT'], ['Base', 'ONT'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'PEOPLEUSDT'], ['Pair', 'PEOPLE/USDT:USDT'], ['Base', 'PEOPLE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'PEOPLEUSDT'], ['Pair', 'PEOPLEUSDT'], ['Base', 'PEOPLE'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'PERPUSDT'], ['Pair', 'PERP/USDT:USDT'], ['Base', 'PERP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'QTUMUSDT'], ['Pair', 'QTUM/USDT:USDT'], ['Base', 'QTUM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'QTUMUSDT'], ['Pair', 'QTUMUSDT'], ['Base', 'QTUM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'RENUSDT'], ['Pair', 'REN/USDT:USDT'], ['Base', 'REN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'RENUSDT'], ['Pair', 'RENUSDT'], ['Base', 'REN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'RSRUSDT'], ['Pair', 'RSR/USDT:USDT'], ['Base', 'RSR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'RSRUSDT'], ['Pair', 'RSRUSDT'], ['Base', 'RSR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'RVNUSDT'], ['Pair', 'RVN/USDT:USDT'], ['Base', 'RVN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'RVNUSDT'], ['Pair', 'RVNUSDT'], ['Base', 'RVN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SANDUSDT'], ['Pair', 'SAND/USDT:USDT'], ['Base', 'SAND'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SANDUSDT'], ['Pair', 'SANDUSDT'], ['Base', 'SAND'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SCUSDT'], ['Pair', 'SC/USDT:USDT'], ['Base', 'SC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SCUSDT'], ['Pair', 'SCUSDT'], ['Base', 'SC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SHIBUSDT'], ['Pair', 'SHIB/USDT:USDT'], ['Base', 'SHIB'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'SLPUSDT'], ['Pair', 'SLP/USDT:USDT'], ['Base', 'SLP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'SNXUSDT'], ['Pair', 'SNX/USDT:USDT'], ['Base', 'SNX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SNXUSDT'], ['Pair', 'SNXUSDT'], ['Base', 'SNX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SOLUSDT'], ['Pair', 'SOL/USDT:USDT'], ['Base', 'SOL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SOLUSDT'], ['Pair', 'SOLUSDT'], ['Base', 'SOL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SOSUSDT'], ['Pair', 'SOS/USDT:USDT'], ['Base', 'SOS'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'SRMUSDT'], ['Pair', 'SRM/USDT:USDT'], ['Base', 'SRM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SRMUSDT'], ['Pair', 'SRMUSDT'], ['Base', 'SRM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'STARLUSDT'], ['Pair', 'STARL/USDT:USDT'], ['Base', 'STARL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'STORJUSDT'], ['Pair', 'STORJ/USDT:USDT'], ['Base', 'STORJ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'STORJUSDT'], ['Pair', 'STORJUSDT'], ['Base', 'STORJ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SUSHIUSDT'], ['Pair', 'SUSHI/USDT:USDT'], ['Base', 'SUSHI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'SUSHIUSDT'], ['Pair', 'SUSHIUSDT'], ['Base', 'SUSHI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'SWRVUSDT'], ['Pair', 'SWRV/USDT:USDT'], ['Base', 'SWRV'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'THETAUSDT'], ['Pair', 'THETA/USDT:USDT'], ['Base', 'THETA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'THETAUSDT'], ['Pair', 'THETAUSDT'], ['Base', 'THETA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'TONCOINUSDT'], ['Pair', 'TONCOIN/USDT:USDT'], ['Base', 'TONCOIN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'TORNUSDT'], ['Pair', 'TORN/USDT:USDT'], ['Base', 'TORN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'TRBUSDT'], ['Pair', 'TRB/USDT:USDT'], ['Base', 'TRB'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'TRBUSDT'], ['Pair', 'TRBUSDT'], ['Base', 'TRB'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'TRXUSDT'], ['Pair', 'TRX/USDT:USDT'], ['Base', 'TRX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'TRXUSDT'], ['Pair', 'TRXUSDT'], ['Base', 'TRX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'UMAUSDT'], ['Pair', 'UMA/USDT:USDT'], ['Base', 'UMA'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'UNIUSDT'], ['Pair', 'UNI/USDT:USDT'], ['Base', 'UNI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'UNIUSDT'], ['Pair', 'UNIUSDT'], ['Base', 'UNI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'WAVESUSDT'], ['Pair', 'WAVES/USDT:USDT'], ['Base', 'WAVES'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'WAVESUSDT'], ['Pair', 'WAVESUSDT'], ['Base', 'WAVES'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'WNCGUSDT'], ['Pair', 'WNCG/USDT:USDT'], ['Base', 'WNCG'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'WNXMUSDT'], ['Pair', 'WNXM/USDT:USDT'], ['Base', 'WNXM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'XCHUSDT'], ['Pair', 'XCH/USDT:USDT'], ['Base', 'XCH'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'XEMUSDT'], ['Pair', 'XEM/USDT:USDT'], ['Base', 'XEM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'XEMUSDT'], ['Pair', 'XEMUSDT'], ['Base', 'XEM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'XLMUSDT'], ['Pair', 'XLM/USDT:USDT'], ['Base', 'XLM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'XLMUSDT'], ['Pair', 'XLMUSDT'], ['Base', 'XLM'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'XMRUSDT'], ['Pair', 'XMR/USDT:USDT'], ['Base', 'XMR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'XMRUSDT'], ['Pair', 'XMRUSDT'], ['Base', 'XMR'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'XRPUSDT'], ['Pair', 'XRP/USDT:USDT'], ['Base', 'XRP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'XRPUSDT'], ['Pair', 'XRPUSDT'], ['Base', 'XRP'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'XTZUSDT'], ['Pair', 'XTZ/USDT:USDT'], ['Base', 'XTZ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'XTZUSDT'], ['Pair', 'XTZUSDT'], ['Base', 'XTZ'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'YFIUSDT'], ['Pair', 'YFI/USDT:USDT'], ['Base', 'YFI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'YFIUSDT'], ['Pair', 'YFIUSDT'], ['Base', 'YFI'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'YFIIUSDT'], ['Pair', 'YFII/USDT:USDT'], ['Base', 'YFII'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'YFIIUSDT'], ['Pair', 'YFIIUSDT'], ['Base', 'YFII'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'YGGUSDT'], ['Pair', 'YGG/USDT:USDT'], ['Base', 'YGG'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# okex/[['Symbol', 'ZECUSDT'], ['Pair', 'ZEC/USDT:USDT'], ['Base', 'ZEC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ZECUSDT'], ['Pair', 'ZECUSDT'], ['Base', 'ZEC'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ZENUSDT'], ['Pair', 'ZEN/USDT:USDT'], ['Base', 'ZEN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ZENUSDT'], ['Pair', 'ZENUSDT'], ['Base', 'ZEN'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ZILUSDT'], ['Pair', 'ZIL/USDT:USDT'], ['Base', 'ZIL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ZILUSDT'], ['Pair', 'ZILUSDT'], ['Base', 'ZIL'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
# okex/[['Symbol', 'ZRXUSDT'], ['Pair', 'ZRX/USDT:USDT'], ['Base', 'ZRX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]
# [["binance/[['Symbol', 'ZRXUSDT'], ['Pair', 'ZRXUSDT'], ['Base', 'ZRX'], ['Quote', 'USDT'], ['Type', 'USDT-PERP']]"]]
